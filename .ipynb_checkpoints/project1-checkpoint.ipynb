# %%
import pandas as pd
import calendar
import seaborn as sns


data3 = pd.read_csv('june30.txt')
data2 = pd.read_csv('june23.txt')
data4 = pd.read_csv('june16.txt')
data = pd.concat([data3,data2,data4],ignore_index = True)

print(data.shape)
print(data2.shape)
print(data3.shape)
data3.head()
# Out:
# (590354, 11)
# (196686, 11)
# (196690, 11)
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/23/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/23/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/23/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/23/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/23/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6667150
# 1  REGULAR  6667173
# 2  REGULAR  6667189
# 3  REGULAR  6667305
# 4  REGULAR  6667534
#
#    EXITS
# 0                                            2259901
# 1                                            2259909
# 2                                            2259938
# 3                                            2260006
# 4                                            2260066

# %%
#data['DATE/TIME'] = pd.to_datetime(data['DATE'] + ' ' + data['TIME'])
data['day'] = pd.to_datetime(data['DATE'])

# %%
by_day = data[(data['TIME']== '00:00:00') & (data['DESC'] == 'REGULAR')]

# %%
by_day.sort_values(['C/A','UNIT','SCP','day'])
by_day.groupby('DESC').count()
# Out:
#            C/A   UNIT    SCP  STATION  LINENAME  DIVISION   DATE   TIME  \
# DESC
# REGULAR  50856  50856  50856    50856     50856     50856  50856  50856
#
#          ENTRIES  \
# DESC
# REGULAR    50856
#
#          EXITS                                                                 \
# DESC
# REGULAR                                              50856
#
#            day
# DESC
# REGULAR  50856

# %%
by_day['COUNT'] = by_day.sort_values(['C/A','UNIT','SCP','day']).groupby(['C/A','UNIT','SCP'])['ENTRIES'].diff()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
by_day['day2'] = by_day['day'] - pd.Timedelta(1,'D')
by_day.head()

Counts_by_turnstile = by_day[['C/A','UNIT','SCP','STATION','day2','COUNT']]
Counts_by_turnstile.dropna(axis=0, inplace=True)
Counts_by_turnstile = Counts_by_turnstile.sort_values(['C/A','UNIT','SCP','day2'])

def data_cleanse(row):
    counter = row['COUNT']
    if counter < 0:
        counter = -counter
    if counter > 90000:
        counter = 0
    return counter

Counts_by_turnstile['Fixed Counts'] = Counts_by_turnstile.apply(data_cleanse, axis=1)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
(
Counts_by_turnstile[(Counts_by_turnstile['STATION'] == '86 ST')
                    & (Counts_by_turnstile['Fixed Counts']>4000)]
)
# Out:
#          C/A  UNIT       SCP STATION       day2   COUNT  Fixed Counts
# 550629  R250  R179  00-00-01   86 ST 2018-06-11  4126.0        4126.0
# 550635  R250  R179  00-00-01   86 ST 2018-06-12  4553.0        4553.0
# 550641  R250  R179  00-00-01   86 ST 2018-06-13  4206.0        4206.0
# 550647  R250  R179  00-00-01   86 ST 2018-06-14  4306.0        4306.0
# 353944  R250  R179  00-00-01   86 ST 2018-06-18  4120.0        4120.0
# 353950  R250  R179  00-00-01   86 ST 2018-06-19  4317.0        4317.0
# 353956  R250  R179  00-00-01   86 ST 2018-06-20  4324.0        4324.0
# 353962  R250  R179  00-00-01   86 ST 2018-06-21  4227.0        4227.0
# 157086  R250  R179  00-00-01   86 ST 2018-06-26  4160.0        4160.0
# 157092  R250  R179  00-00-01   86 ST 2018-06-27  4273.0        4273.0
# 551055  R250  R179  00-00-0B   86 ST 2018-06-12  4457.0        4457.0
# 551061  R250  R179  00-00-0B   86 ST 2018-06-13  4347.0        4347.0
# 551067  R250  R179  00-00-0B   86 ST 2018-06-14  4352.0        4352.0
# 354346  R250  R179  00-00-0B   86 ST 2018-06-15  4204.0        4204.0
# 354370  R250  R179  00-00-0B   86 ST 2018-06-19  4231.0        4231.0
# 354376  R250  R179  00-00-0B   86 ST 2018-06-20  4139.0        4139.0
# 354382  R250  R179  00-00-0B   86 ST 2018-06-21  4080.0        4080.0
# 157482  R250  R179  00-00-0B   86 ST 2018-06-22  4257.0        4257.0
# 157506  R250  R179  00-00-0B   86 ST 2018-06-26  4172.0        4172.0
# 157512  R250  R179  00-00-0B   86 ST 2018-06-27  4209.0        4209.0
# 157518  R250  R179  00-00-0B   86 ST 2018-06-28  4043.0        4043.0

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
(
plt.plot(Counts_by_turnstile[(Counts_by_turnstile['SCP']=='02-00-00')
        & (Counts_by_turnstile['STATION']=='59 ST')]['day2']
        ,Counts_by_turnstile[(Counts_by_turnstile['SCP']=='02-00-00')
        & (Counts_by_turnstile['STATION']=='59 ST')]['Fixed Counts'])
)

# %%
count_by_station = Counts_by_turnstile.groupby(['STATION','day2'])['Fixed Counts'].sum().reset_index()

count_by_station['Name_of_Day'] = count_by_station['day2'].dt.weekday_name
count_by_station['Week Number'] = count_by_station['day2'].dt.week
print(count_by_station)
# Out:
#               STATION       day2  Fixed Counts Name_of_Day  Week Number
# 0                1 AV 2018-06-09       18889.0    Saturday           23
# 1                1 AV 2018-06-10       14367.0      Sunday           23
# 2                1 AV 2018-06-11       21548.0      Monday           24
# 3                1 AV 2018-06-12       22581.0     Tuesday           24
# 4                1 AV 2018-06-13       22684.0   Wednesday           24
# 5                1 AV 2018-06-14       23746.0    Thursday           24
# 6                1 AV 2018-06-15       22554.0      Friday           24
# 7                1 AV 2018-06-16       17680.0    Saturday           24
# 8                1 AV 2018-06-17       13188.0      Sunday           24
# 9                1 AV 2018-06-18       20441.0      Monday           25
# 10               1 AV 2018-06-19       20255.0     Tuesday           25
# 11               1 AV 2018-06-20       22309.0   Wednesday           25
# 12               1 AV 2018-06-21       23079.0    Thursday           25
# 13               1 AV 2018-06-22       23467.0      Friday           25
# 14               1 AV 2018-06-23       17425.0    Saturday           25
# 15               1 AV 2018-06-24       16773.0      Sunday           25
# 16               1 AV 2018-06-25       20294.0      Monday           26
# 17               1 AV 2018-06-26       21530.0     Tuesday           26
# 18               1 AV 2018-06-27       20989.0   Wednesday           26
# 19               1 AV 2018-06-28       21499.0    Thursday           26
# 20      103 ST-CORONA 2018-06-09       15283.0    Saturday           23
# 21      103 ST-CORONA 2018-06-10       11351.0      Sunday           23
# 22      103 ST-CORONA 2018-06-11       20239.0      Monday           24
# 23      103 ST-CORONA 2018-06-12       20035.0     Tuesday           24
# 24      103 ST-CORONA 2018-06-13       20150.0   Wednesday           24
# 25      103 ST-CORONA 2018-06-14       20342.0    Thursday           24
# 26      103 ST-CORONA 2018-06-15       19754.0      Friday           24
# 27      103 ST-CORONA 2018-06-16       14858.0    Saturday           24
# 28      103 ST-CORONA 2018-06-17       10218.0      Sunday           24
# 29      103 ST-CORONA 2018-06-18       19101.0      Monday           25
# ...               ...        ...           ...         ...          ...
# 4148         WOODLAWN 2018-06-19        7658.0     Tuesday           25
# 4149         WOODLAWN 2018-06-20        7553.0   Wednesday           25
# 4150         WOODLAWN 2018-06-21        7593.0    Thursday           25
# 4151         WOODLAWN 2018-06-22        7209.0      Friday           25
# 4152         WOODLAWN 2018-06-23        4433.0    Saturday           25
# 4153         WOODLAWN 2018-06-24        3673.0      Sunday           25
# 4154         WOODLAWN 2018-06-25        7258.0      Monday           26
# 4155         WOODLAWN 2018-06-26        7388.0     Tuesday           26
# 4156         WOODLAWN 2018-06-27        6989.0   Wednesday           26
# 4157         WOODLAWN 2018-06-28        6947.0    Thursday           26
# 4158  WORLD TRADE CTR 2018-06-09        9887.0    Saturday           23
# 4159  WORLD TRADE CTR 2018-06-10        7351.0      Sunday           23
# 4160  WORLD TRADE CTR 2018-06-11       19425.0      Monday           24
# 4161  WORLD TRADE CTR 2018-06-12       20800.0     Tuesday           24
# 4162  WORLD TRADE CTR 2018-06-13       20373.0   Wednesday           24
# 4163  WORLD TRADE CTR 2018-06-14       21024.0    Thursday           24
# 4164  WORLD TRADE CTR 2018-06-15       19526.0      Friday           24
# 4165  WORLD TRADE CTR 2018-06-16        9118.0    Saturday           24
# 4166  WORLD TRADE CTR 2018-06-17        6294.0      Sunday           24
# 4167  WORLD TRADE CTR 2018-06-18       18273.0      Monday           25
# 4168  WORLD TRADE CTR 2018-06-19       19320.0     Tuesday           25
# 4169  WORLD TRADE CTR 2018-06-20       19387.0   Wednesday           25
# 4170  WORLD TRADE CTR 2018-06-21       19877.0    Thursday           25
# 4171  WORLD TRADE CTR 2018-06-22       18966.0      Friday           25
# 4172  WORLD TRADE CTR 2018-06-23        8066.0    Saturday           25
# 4173  WORLD TRADE CTR 2018-06-24        6818.0      Sunday           25
# 4174  WORLD TRADE CTR 2018-06-25       19433.0      Monday           26
# 4175  WORLD TRADE CTR 2018-06-26       19077.0     Tuesday           26
# 4176  WORLD TRADE CTR 2018-06-27       18745.0   Wednesday           26
# 4177  WORLD TRADE CTR 2018-06-28       19996.0    Thursday           26
#
# [4178 rows x 5 columns]

# %%
def fixed_week(row):
    week = row['Week Number']
    if row['Name_of_Day'] == 'Saturday':
        week += 1
    elif row['Name_of_Day'] == 'Sunday':
        week += 1
    return week

count_by_station['Week Number'] = count_by_station.apply(fixed_week, axis=1)

# %%
mask = (count_by_station['STATION'] == '86 ST')
print(count_by_station[mask])
# Out:
#      STATION       day2  Fixed Counts Name_of_Day  Week Number
# 1431   86 ST 2018-06-09       35768.0    Saturday           24
# 1432   86 ST 2018-06-10       28398.0      Sunday           24
# 1433   86 ST 2018-06-11       54908.0      Monday           24
# 1434   86 ST 2018-06-12       61260.0     Tuesday           24
# 1435   86 ST 2018-06-13       59138.0   Wednesday           24
# 1436   86 ST 2018-06-14       57875.0    Thursday           24
# 1437   86 ST 2018-06-15       55163.0      Friday           24
# 1438   86 ST 2018-06-16       32214.0    Saturday           25
# 1439   86 ST 2018-06-17       22987.0      Sunday           25
# 1440   86 ST 2018-06-18       52672.0      Monday           25
# 1441   86 ST 2018-06-19       58235.0     Tuesday           25
# 1442   86 ST 2018-06-20       57188.0   Wednesday           25
# 1443   86 ST 2018-06-21       56549.0    Thursday           25
# 1444   86 ST 2018-06-22       55177.0      Friday           25
# 1445   86 ST 2018-06-23       38461.0    Saturday           26
# 1446   86 ST 2018-06-24       25527.0      Sunday           26
# 1447   86 ST 2018-06-25       52921.0      Monday           26
# 1448   86 ST 2018-06-26       56814.0     Tuesday           26
# 1449   86 ST 2018-06-27       54868.0   Wednesday           26
# 1450   86 ST 2018-06-28       53279.0    Thursday           26

# %%
sns.set()
sns.factorplot(x='Name_of_Day',y='Fixed Counts',hue ='Week Number', size=7, data = count_by_station[mask]);

# %%
totals_by_station = count_by_station.groupby(['STATION'])['Fixed Counts'].sum().reset_index()

# %%
totals_by_station = totals_by_station.sort_values('Fixed Counts', ascending = False)

# %%
totals_by_station.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a2b7f0fd0>]],
#       dtype=object)

# %%
print(totals_by_station)
# Out:
#              STATION  Fixed Counts
# 39   34 ST-HERALD SQ     2253692.0
# 41    34 ST-PENN STA     1990784.0
# 198   TIMES SQ-42 ST     1872080.0
# 142  GRD CNTRL-42 ST     1349603.0
# 31             23 ST     1303472.0
# 60    59 ST COLUMBUS     1253879.0
# 59             59 ST     1204449.0
# 47   42 ST-PORT AUTH     1175197.0
# 133    FLUSHING-MAIN     1004030.0
# 50    47-50 STS ROCK      970347.0
# 114      CHAMBERS ST      969557.0
# 73             86 ST      969402.0
# 154  JKSN HT-ROOSVLT      898908.0
# 54             50 ST      865907.0
# 79    ATL AV-BARCLAY      780626.0
# 46   42 ST-BRYANT PK      737470.0
# 9              14 ST      717866.0
# 152  JAY ST-METROTEC      685486.0
# 160  LEXINGTON AV/53      675841.0
# 6             125 ST      655070.0
# 58        57 ST-7 AV      649003.0
# 126        DEKALB AV      621530.0
# 10            145 ST      619153.0
# 151   JAMAICA CENTER      616272.0
# 100     BOROUGH HALL      593599.0
# 93        BEDFORD AV      562760.0
# 139         GRAND ST      561272.0
# 102    BOWLING GREEN      534397.0
# 51             49 ST      485839.0
# 13            168 ST      475696.0
# ..               ...           ...
# 65    74 ST-BROADWAY       60480.0
# 96         BERGEN ST       60471.0
# 174       OCEAN PKWY       60238.0
# 66             75 AV       59377.0
# 163  METROPOLITAN AV       59340.0
# 67     75 ST-ELDERTS       58716.0
# 203  W 8 ST-AQUARIUM       58536.0
# 37             30 AV       57750.0
# 81          AVENUE H       55314.0
# 8     138/GRAND CONC       54624.0
# 85          AVENUE X       50775.0
# 177       PARK PLACE       49007.0
# 92       BEACH 67 ST       47618.0
# 76   AQUEDUCT RACETR       44411.0
# 201    VAN SICLEN AV       43186.0
# 109      BUSHWICK AV       40370.0
# 91       BEACH 60 ST       39616.0
# 57             55 ST       36941.0
# 80       ATLANTIC AV       33889.0
# 88       BEACH 25 ST       32319.0
# 206      WHITLOCK AV       31338.0
# 156        JUNIUS ST       30958.0
# 30            215 ST       28584.0
# 42             36 AV       26076.0
# 125    CYPRESS HILLS       24664.0
# 84          AVENUE P       23124.0
# 5             121 ST       21558.0
# 89       BEACH 36 ST       17019.0
# 90       BEACH 44 ST       13326.0
# 175    ORCHARD BEACH         312.0
#
# [211 rows x 2 columns]
